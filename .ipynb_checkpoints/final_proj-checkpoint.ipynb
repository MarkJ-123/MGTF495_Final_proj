# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.naive_bayes import GaussianNB, MultinomialNB
import category_encoders as ce
import warnings
warnings.filterwarnings('ignore')

# %%
# Read data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is : {} ".format(train.shape))
print("The test data size before dropping Id feature is : {} ".format(test.shape))

#Save the 'Id' column
train_ID = train['ID']
test_ID = test['ID']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("ID", axis = 1, inplace = True)
test.drop("ID", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size before dropping Id feature is : (2051, 81)
# The test data size before dropping Id feature is : (879, 80)
#
# The train data size after dropping Id feature is : (2051, 80)
# The test data size after dropping Id feature is : (879, 79)

# %%
#test['Kitchens']

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
train
# Out:
#         Paved Drive   BsmtExposure  BsmtUnfinishedArea  ProximityToMainRoad2  \
# 0     223816.720564  196355.576208              2073.0         215217.125799
# 1     223816.720564  196355.576208              1624.0         215217.125799
# 2     223816.720564  231365.817535              1007.0         215217.125799
# 3     223816.720564  196355.576208               582.0         215217.125799
# 4     223816.720564  196355.576208              1299.0         215088.769868
# ...             ...            ...                 ...                   ...
# 2046  223816.720564  196355.576208              1272.0         215217.125799
# 2047  223816.720564  196355.576208               781.0         215217.125799
# 2048  223816.720564  196355.576208              1646.0         215217.125799
# 2049  223816.720564  312116.348679               605.0         215217.125799
# 2050  223816.720564  196355.576208               567.0         215217.125799
#
# ...

# %%
#fill missing value in the train data
#tPaved Drive
train['Paved Drive'].value_counts()
train['Paved Drive'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Paved Drive'], train['SalePrice'])
train.loc[(train['Paved Drive'].isnull()),'Paved Drive'] = train['Paved Drive'].mean()

# %%
#BsmtExposure
train['BsmtExposure'].value_counts()
train['BsmtExposure'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtExposure'], train['SalePrice'])
train.loc[(train['BsmtExposure'].isnull()),'BsmtExposure'] = train['BsmtExposure'].mean()

# %%
#ProximityToMainRoad2
train['ProximityToMainRoad2'].value_counts()
train['ProximityToMainRoad2'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ProximityToMainRoad2'], train['SalePrice'])
train.loc[(train['ProximityToMainRoad2'].isnull()),'ProximityToMainRoad2'] = train['ProximityToMainRoad2'].mean()

# %%
#KitchenQuality
train['KitchenQuality'].value_counts()
train['KitchenQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['KitchenQuality'], train['SalePrice'])
train.loc[(train['KitchenQuality'].isnull()),'KitchenQuality'] = train['KitchenQuality'].mean()

# %%
#SaleCondition
train['SaleCondition'].value_counts()
train['SaleCondition'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['SaleCondition'], train['SalePrice'])
train.loc[(train['SaleCondition'].isnull()),'SaleCondition'] = train['SaleCondition'].mean()

# %%
#Lot Config
train['Lot Config'].value_counts()
train['Lot Config'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Lot Config'], train['SalePrice'])
train.loc[(train['Lot Config'].isnull()),'Lot Config'] = train['Lot Config'].mean()

# %%
#FenceQuality
train['FenceQuality'].value_counts()
train['FenceQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['FenceQuality'], train['SalePrice'])
train.loc[(train['FenceQuality'].isnull()),'FenceQuality'] = train['FenceQuality'].mean()

# %%
#SaleType
train['SaleType'].value_counts()
train['SaleType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['SaleType'], train['SalePrice'])
train.loc[(train['SaleType'].isnull()),'SaleType'] = train['SaleType'].mean()

# %%
#Neighborhood
train['Neighborhood'].value_counts()
train['Neighborhood'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Neighborhood'], train['SalePrice'])

# %%
#HeatingQuality
train['HeatingQuality'].value_counts()
train['HeatingQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HeatingQuality'], train['SalePrice'])
train.loc[(train['HeatingQuality'].isnull()),'HeatingQuality'] = train['HeatingQuality'].mean()

# %%
#RoofMaterial
train['RoofMaterial'].value_counts()
train['RoofMaterial'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['RoofMaterial'], train['SalePrice'])
train.loc[(train['RoofMaterial'].isnull()),'RoofMaterial'] = train['RoofMaterial'].mean()

# %%
#Exterior1
train['Exterior1'].value_counts()
train['Exterior1'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Exterior1'], train['SalePrice'])
train.loc[(train['Exterior1'].isnull()),'Exterior1'] = train['Exterior1'].mean()

# %%
#Foundation
train['Foundation'].value_counts()
train['Foundation'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Foundation'], train['SalePrice'])
train.loc[(train['Foundation'].isnull()),'Foundation'] = train['Foundation'].mean()

# %%
#HouseType
train['HouseType'].value_counts()
train['HouseType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HouseType'], train['SalePrice'])
train.loc[(train['HouseType'].isnull()),'HouseType'] = train['HouseType'].mean()

# %%
#YearRemodelled	
train['Misc Feature'].value_counts()
train['Misc Feature'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Misc Feature'], train['SalePrice'])
train.loc[(train['Misc Feature'].isnull()),'Misc Feature'] = train['Misc Feature'].mean()

# %%
#GarageFinish
train['GarageFinish'].value_counts()
train['GarageFinish'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['GarageFinish'], train['SalePrice'])
train.loc[(train['GarageFinish'].isnull()),'GarageFinish'] = train['GarageFinish'].mean()

# %%
#ExteriorQual
train['ExteriorQual'].value_counts()
train['ExteriorQual'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ExteriorQual'], train['SalePrice'])
train.loc[(train['ExteriorQual'].isnull()),'ExteriorQual'] = train['ExteriorQual'].mean()

# %%
#UtilitiesAvailable
train['UtilitiesAvailable'].value_counts()
train['UtilitiesAvailable'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['UtilitiesAvailable'], train['SalePrice'])
train.loc[(train['UtilitiesAvailable'].isnull()),'UtilitiesAvailable'] = train['UtilitiesAvailable'].mean()

# %%
#HouseStyle
train['HouseStyle'].value_counts()
train['HouseStyle'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HouseStyle'], train['SalePrice'])
train.loc[(train['HouseStyle'].isnull()),'HouseStyle'] = train['HouseStyle'].mean()

# %%
#MasVnrType
train['MasVnrType'].value_counts()
train['MasVnrType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['MasVnrType'], train['SalePrice'])
train.loc[(train['MasVnrType'].isnull()),'MasVnrType'] = train['MasVnrType'].mean()

# %%
#FireplaceQuality
train['FireplaceQuality'].value_counts()
train['FireplaceQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['FireplaceQuality'], train['SalePrice'])
train.loc[(train['FireplaceQuality'].isnull()),'FireplaceQuality'] = train['FireplaceQuality'].mean()

# %%
#BsmtCondition
train['BsmtCondition'].value_counts()
train['BsmtCondition'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtCondition'], train['SalePrice'])
train.loc[(train['BsmtCondition'].isnull()),'BsmtCondition'] = train['BsmtCondition'].mean()

# %%
#BsmtHeight
train['BsmtHeight'].value_counts()
train['BsmtHeight'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtHeight'], train['SalePrice'])
train.loc[(train['BsmtHeight'].isnull()),'BsmtHeight'] = train['BsmtHeight'].mean()

# %%
#BsmtFinishType2
train['BsmtFinishType2'].value_counts()
train['BsmtFinishType2'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtFinishType2'], train['SalePrice'])
train.loc[(train['BsmtFinishType2'].isnull()),'BsmtFinishType2'] = train['BsmtFinishType2'].mean()

# %%
#PoolQuality
train['PoolQuality'].value_counts()
train['PoolQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['PoolQuality'], train['SalePrice'])
train.loc[(train['PoolQuality'].isnull()),'PoolQuality'] = train['PoolQuality'].mean()

# %%
#RoofType
train['RoofType'].value_counts()
train['RoofType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['RoofType'], train['SalePrice'])
train.loc[(train['RoofType'].isnull()),'RoofType'] = train['RoofType'].mean()

# %%
#Functional
train['Functional'].value_counts()
train['Functional'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Functional'], train['SalePrice'])
train.loc[(train['Functional'].isnull()),'Functional'] = train['Functional'].mean()

# %%
#ExteriorCond
train['ExteriorCond'].value_counts()
train['ExteriorCond'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ExteriorCond'], train['SalePrice'])
train.loc[(train['ExteriorCond'].isnull()),'ExteriorCond'] = train['ExteriorCond'].mean()

# %%
#GarageCondition
train['GarageCondition'].value_counts()
train['GarageCondition'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['GarageCondition'], train['SalePrice'])
train.loc[(train['GarageCondition'].isnull()),'GarageCondition'] = train['GarageCondition'].mean()

# %%
#Electrical
train['Electrical'].value_counts()
train['Electrical'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Electrical'], train['SalePrice'])
train.loc[(train['Electrical'].isnull()),'Electrical'] = train['Electrical'].mean()

# %%
#ProximityToMainRoad
train['ProximityToMainRoad'].value_counts()
train['ProximityToMainRoad'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ProximityToMainRoad'], train['SalePrice'])
train.loc[(train['ProximityToMainRoad'].isnull()),'ProximityToMainRoad'] = train['ProximityToMainRoad'].mean()

# %%
#GarageQuality
train['GarageQuality'].value_counts()
train['GarageQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['GarageQuality'], train['SalePrice'])
train.loc[(train['GarageQuality'].isnull()),'GarageQuality'] = train['GarageQuality'].mean()

# %%
#ZoningClass
train['ZoningClass'].value_counts()
train['ZoningClass'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ZoningClass'], train['SalePrice'])
train.loc[(train['ZoningClass'].isnull()),'ZoningClass'] = train['ZoningClass'].mean()

# %%
#TypeOfAlleyAccess
train['TypeOfAlleyAccess'].value_counts()
train['TypeOfAlleyAccess'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['TypeOfAlleyAccess'], train['SalePrice'])
train.loc[(train['TypeOfAlleyAccess'].isnull()),'TypeOfAlleyAccess'] = train['TypeOfAlleyAccess'].mean()

# %%
#BsmtFinishType1
train['BsmtFinishType1'].value_counts()
train['BsmtFinishType1'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtFinishType1'], train['SalePrice'])
train.loc[(train['BsmtFinishType1'].isnull()),'BsmtFinishType1'] = train['BsmtFinishType1'].mean()

# %%
#TypeOfRoadAccess
train['TypeOfRoadAccess'].value_counts()
train['TypeOfRoadAccess'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['TypeOfRoadAccess'], train['SalePrice'])
train.loc[(train['TypeOfRoadAccess'].isnull()),'TypeOfRoadAccess'] = train['TypeOfRoadAccess'].mean()

# %%
#Shape
train['Shape'].value_counts()
train['Shape'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Shape'], train['SalePrice'])
train.loc[(train['Shape'].isnull()),'Shape'] = train['Shape'].mean()

# %%
#Flatness
train['Flatness'].value_counts()
train['Flatness'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Flatness'], train['SalePrice'])
train.loc[(train['Flatness'].isnull()),'Flatness'] = train['Flatness'].mean()

# %%
#HeatingType
train['HeatingType'].value_counts()
train['HeatingType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HeatingType'], train['SalePrice'])
train.loc[(train['HeatingType'].isnull()),'HeatingType'] = train['HeatingType'].mean()

# %%
#Central Air
train['Central Air'].value_counts()
train['Central Air'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Central Air'], train['SalePrice'])
train.loc[(train['Central Air'].isnull()),'Central Air'] = train['Central Air'].mean()

# %%
#SlopeOfProperty
train['SlopeOfProperty'].value_counts()
train['SlopeOfProperty'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['SlopeOfProperty'], train['SalePrice'])
train.loc[(train['SlopeOfProperty'].isnull()),'SlopeOfProperty'] = train['SlopeOfProperty'].mean()

# %%
#Exterior2
train['Exterior2'].value_counts()
train['Exterior2'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Exterior2'], train['SalePrice'])
train.loc[(train['Exterior2'].isnull()),'Exterior2'] = train['Exterior2'].mean()

# %%
#GarageType
train['GarageType'].value_counts()
train['GarageType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['GarageType'], train['SalePrice'])
train.loc[(train['GarageType'].isnull()),'GarageType'] = train['GarageType'].mean()

# %%
#GarageYearBuilt
train['GarageType'].value_counts()
train.loc[train['GarageYearBuilt'].isnull(),'GarageYearBuilt'] = train['YearBuilt']

# %%
train.loc[(train['GarageCars'].isnull()),'GarageCars'] = 0
train.loc[(train['FullBaths'].isnull()),'FullBaths'] = 0
train.loc[(train['BsmtHalfBaths'].isnull()),'BsmtHalfBaths'] = 0
train.loc[(train['LowQualityFinishArea'].isnull()),'LowQualityFinishArea'] = 0
train.loc[(train['SeasonPorchArea'].isnull()),'SeasonPorchArea'] = 0
train.loc[(train['BsmtFinish2Area'].isnull()),'BsmtFinish2Area'] = 0
train.loc[(train['TotalRooms'].isnull()),'TotalRooms'] = 0
train.loc[(train['Misc'].isnull()),'Misc'] = 0
train.loc[(train['ScreenPorchArea'].isnull()),'ScreenPorchArea'] = 0
train.loc[(train['BsmtFullBaths'].isnull()),'BsmtFullBaths'] = 0
train.loc[(train['PoolSize'].isnull()),'PoolSize'] = 0
train.loc[(train['EnclosedPorchArea'].isnull()),'EnclosedPorchArea'] = 0
train.loc[(train['LivingArea'].isnull()),'LivingArea'] = train['LivingArea'].mean()
train.loc[(train['TotalBsmtArea'].isnull()),'TotalBsmtArea'] = train['TotalBsmtArea'].mean()
train.loc[(train['HalfBaths'].isnull()),'HalfBaths'] = 0
train.loc[(train['BsmtUnfinishedArea'].isnull()),'BsmtUnfinishedArea'] = train['BsmtUnfinishedArea'].mean()
train.loc[(train['LotFrontage'].isnull()),'LotFrontage'] = train['LotFrontage'].mean()
train.loc[(train['MasVnrArea'].isnull()),'MasVnrArea'] = 0
train.loc[(train['OpenPorchArea'].isnull()),'OpenPorchArea'] = train['OpenPorchArea'].mean()
train.loc[(train['Fireplaces'].isnull()),'Fireplaces'] = 0
train.loc[(train['TotalBsmtArea'].isnull()),'TotalBsmtArea'] = train['TotalBsmtArea'].mean()
train.loc[(train['WoodDeckArea'].isnull()),'WoodDeckArea'] = 0
train.loc[(train['Bedrooms'].isnull()),'Bedrooms'] = 0
train.loc[(train['FullBaths'].isnull()),'FullBaths'] = 0
train.loc[(train['OverallRating'].isnull()),'OverallRating'] = 5
train.loc[(train['GarageArea'].isnull()),'GarageArea'] = train['GarageArea'].mean()
train.loc[(train['BsmtFinish1Area'].isnull()),'BsmtFinish1Area'] = train['BsmtFinish1Area'].mean()
train.loc[(train['Quality'].isnull()),'Quality'] = 5
train.loc[(train['LotSize'].isnull()),'LotSize'] = train['LotSize'].mean()
train.loc[(train['Kitchens'].isnull()),'Kitchens'] = 0
train.loc[(train['BuildingClass'].isnull()),'BuildingClass'] = train['BuildingClass'].mean()
train.loc[(train['2ndFloorArea'].isnull()),'2ndFloorArea'] = train['2ndFloorArea'].mean()
train.loc[(train['1stFloorArea'].isnull()),'1stFloorArea'] = train['1stFloorArea'].mean()

# %%
X_train, X_val, y_train, y_val = train_test_split(train, train['SalePrice'], test_size=0.2, random_state=5)

# %%
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, y_train)
prediction = clf.predict(X_val)
y_pred_1 = clf.predict(X_val)
print ('valid accuracy = ' + str(accuracy_score(y_val,y_pred_1)))
# Out:
# valid accuracy = 0.5158150851581509

# %%
def rmse(y_true, y_pred):
    """Root Mean Squared Error"""
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ## `SalePrice` Baseline
# ### Predict the global average sale price.

# %%
test['Paved Drive'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Paved Drive'], train['SalePrice'])
test.loc[(test['Paved Drive'].isnull()),'Paved Drive'] = test['Paved Drive'].mean()
test['BsmtExposure'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['BsmtExposure'], train['SalePrice'])
test.loc[(test['BsmtExposure'].isnull()),'BsmtExposure'] = test['BsmtExposure'].mean()
test['ProximityToMainRoad2'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ProximityToMainRoad2'], train['SalePrice'])
test.loc[(test['ProximityToMainRoad2'].isnull()),'ProximityToMainRoad2'] = test['ProximityToMainRoad2'].mean()
test['KitchenQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['KitchenQuality'], train['SalePrice'])
test.loc[(test['KitchenQuality'].isnull()),'KitchenQuality'] = test['KitchenQuality'].mean()
test['SaleCondition'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['SaleCondition'], train['SalePrice'])
test.loc[(test['SaleCondition'].isnull()),'SaleCondition'] = test['SaleCondition'].mean()
test['Lot Config'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Lot Config'], train['SalePrice'])
test.loc[(test['Lot Config'].isnull()),'Lot Config'] = test['Lot Config'].mean()
test['FenceQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['FenceQuality'], train['SalePrice'])
test.loc[(test['FenceQuality'].isnull()),'FenceQuality'] = test['FenceQuality'].mean()
test['SaleType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['SaleType'], train['SalePrice'])
test.loc[(test['SaleType'].isnull()),'SaleType'] = test['SaleType'].mean()
test['Neighborhood'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Neighborhood'], train['SalePrice'])
test.loc[(test['Neighborhood'].isnull()),'Neighborhood'] = test['Neighborhood'].mean()
test['HeatingQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HeatingQuality'], train['SalePrice'])
test.loc[(test['HeatingQuality'].isnull()),'HeatingQuality'] = test['HeatingQuality'].mean()
test['RoofMaterial'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['RoofMaterial'], train['SalePrice'])
test.loc[(test['RoofMaterial'].isnull()),'RoofMaterial'] = test['RoofMaterial'].mean()
test['Exterior1'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Exterior1'], train['SalePrice'])
test.loc[(test['Exterior1'].isnull()),'Exterior1'] = test['Exterior1'].mean()
test['Foundation'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Foundation'], train['SalePrice'])
test.loc[(test['Foundation'].isnull()),'Foundation'] = test['Foundation'].mean()
test['HouseType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HouseType'], train['SalePrice'])
test.loc[(test['HouseType'].isnull()),'HouseType'] = test['HouseType'].mean()
test['Misc Feature'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['Misc Feature'], train['SalePrice'])
test.loc[(test['Misc Feature'].isnull()),'Misc Feature'] = test['Misc Feature'].mean()
test['GarageFinish'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['GarageFinish'], train['SalePrice'])
test.loc[(test['GarageFinish'].isnull()),'GarageFinish'] = test['GarageFinish'].mean()
test['ExteriorQual'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['ExteriorQual'], train['SalePrice'])
test.loc[(test['ExteriorQual'].isnull()),'ExteriorQual'] = test['ExteriorQual'].mean()
test['UtilitiesAvailable'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['UtilitiesAvailable'], train['SalePrice'])
test.loc[(test['UtilitiesAvailable'].isnull()),'UtilitiesAvailable'] = test['UtilitiesAvailable'].mean()
test['HouseStyle'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['HouseStyle'], train['SalePrice'])
test.loc[(test['HouseStyle'].isnull()),'HouseStyle'] = test['HouseStyle'].mean()
test['MasVnrType'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['MasVnrType'], train['SalePrice'])
test.loc[(test['MasVnrType'].isnull()),'MasVnrType'] = test['MasVnrType'].mean()
test['FireplaceQuality'] = ce.TargetEncoder(smoothing = 15).fit_transform(train['FireplaceQuality'], train['SalePrice'])
test.loc[(test['FireplaceQuality'].isnull()),'FireplaceQuality'] = train['FireplaceQuality'].mean()

# %%
# Out:
# 223816.720564    1843
# 129414.046690     161
# 168499.949187      47
# Name: Paved Drive, dtype: int64

# %%
# Out:
# 223816.720564    803
# 129414.046690     61
# 168499.949187     15
# Name: Paved Drive, dtype: int64

# %%
test.loc[(train['GarageCars'].isnull()),'GarageCars'] = 0
test.loc[(train['FullBaths'].isnull()),'FullBaths'] = 0
test.loc[(train['BsmtHalfBaths'].isnull()),'BsmtHalfBaths'] = 0
test.loc[(train['LowQualityFinishArea'].isnull()),'LowQualityFinishArea'] = 0
test.loc[(train['SeasonPorchArea'].isnull()),'SeasonPorchArea'] = 0
test.loc[(train['BsmtFinish2Area'].isnull()),'BsmtFinish2Area'] = 0
test.loc[(train['TotalRooms'].isnull()),'TotalRooms'] = 0
test.loc[(train['Misc'].isnull()),'Misc'] = 0
test.loc[(train['ScreenPorchArea'].isnull()),'ScreenPorchArea'] = 0
test.loc[(train['BsmtFullBaths'].isnull()),'BsmtFullBaths'] = 0
test.loc[(train['PoolSize'].isnull()),'PoolSize'] = 0
test.loc[(train['EnclosedPorchArea'].isnull()),'EnclosedPorchArea'] = 0
test.loc[(train['LivingArea'].isnull()),'LivingArea'] = test['LivingArea'].mean()
test.loc[(train['TotalBsmtArea'].isnull()),'TotalBsmtArea'] = test['TotalBsmtArea'].mean()
test.loc[(train['HalfBaths'].isnull()),'HalfBaths'] = 0
test.loc[(train['BsmtUnfinishedArea'].isnull()),'BsmtUnfinishedArea'] = test['BsmtUnfinishedArea'].mean()
test.loc[(train['LotFrontage'].isnull()),'LotFrontage'] = test['LotFrontage'].mean()
test.loc[(train['MasVnrArea'].isnull()),'MasVnrArea'] = 0
test.loc[(train['OpenPorchArea'].isnull()),'OpenPorchArea'] = test['OpenPorchArea'].mean()
test.loc[(train['Fireplaces'].isnull()),'Fireplaces'] = 0
test.loc[(train['TotalBsmtArea'].isnull()),'TotalBsmtArea'] = test['TotalBsmtArea'].mean()
test.loc[(train['WoodDeckArea'].isnull()),'WoodDeckArea'] = 0
test.loc[(train['Bedrooms'].isnull()),'Bedrooms'] = 0
test.loc[(train['FullBaths'].isnull()),'FullBaths'] = 0
test.loc[(train['OverallRating'].isnull()),'OverallRating'] = 5
test.loc[(train['GarageArea'].isnull()),'GarageArea'] = test['GarageArea'].mean()
test.loc[(train['BsmtFinish1Area'].isnull()),'BsmtFinish1Area'] = test['BsmtFinish1Area'].mean()
test.loc[(train['Quality'].isnull()),'Quality'] = 5
test.loc[(train['LotSize'].isnull()),'LotSize'] = test['LotSize'].mean()
test.loc[(train['Kitchens'].isnull()),'Kitchens'] = 0
test.loc[(train['BuildingClass'].isnull()),'BuildingClass'] = test['BuildingClass'].mean()
test.loc[(train['2ndFloorArea'].isnull()),'2ndFloorArea'] = test['2ndFloorArea'].mean()
test.loc[(train['1stFloorArea'].isnull()),'1stFloorArea'] = test['1stFloorArea'].mean()

# %%
new_test = test[['LivingArea', 'TotalBsmtArea','BsmtUnfinishedArea','LotFrontage','TotalBsmtArea','Bedrooms','FullBaths',
                                                        'OverallRating','GarageArea','BsmtFinish1Area','Quality',
                                                        'LotSize','Kitchens','BuildingClass','2ndFloorArea','1stFloorArea']].fillna(0)
predictions_1 = mnb.predict(new_test)
y_pred = predictions_1

# %%
#rmse(y_true,y_pred)

# %% [markdown]
# # Submission

# %%
# create submission file
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = y_pred
sub.to_csv('submission.csv',index=False)

# %%
sub
# Out:
#        Id  SalePrice
# 0    2051     393556
# 1    2052     278606
# 2    2053     146606
# 3    2054     262656
# 4    2055     223606
# 5    2056     277506
# 6    2057     106456
# 7    2058     280256
# 8    2059     328106
# 9    2060     230977
# 10   2061     214476
# 11   2062     155516
# 12   2063     567429
# 13   2064     356189
# 14   2065     214987
# 15   2066     313806
# 16   2067     211506
# 17   2068     121856
# 18   2069     295656
# 19   2070     192733
# 20   2071     474183
# 21   2072     152216
# 22   2073     278606
# 23   2074     432524
# 24   2075     253746
# 25   2076     171246
# 26   2077     148099
# 27   2078     668101
# 28   2079     178836
# 29   2080     266781
# 30   2081     330306
# 31   2082     385856
# 32   2083     624556
# 33   2084     506856
# 34   2085     195281
# 35   2086     268706
# 36   2087     226246
# 37   2088     283006
# 38   2089     190606
# 39   2090      86656
# 40   2091     239336
# 41   2092     205456
# ...
